# %%
#import face_recognition

#img = face_recognition.load_image_file("alice.jpg")
#encoding = face_recognition.face_encodings(img)[0]
#print(encoding)

# %%
import os
import numpy as np
def load_data_with_paths(data_dir="dataset", img_size=(64, 64)):
    sets = ["train", "test"]
    classes = ["no_face", "face"]

    data = {}
    paths_data = {}

    for s in sets:
        X = []
        y = []
        paths = []

        for label, cls in enumerate(classes):
            class_dir = os.path.join(data_dir, s, cls)

            for file in os.listdir(class_dir):
                img_path = os.path.join(class_dir, file)

                try:
                    img = Image.open(img_path).convert("RGB")
                    img = img.resize(img_size)
                    X.append(np.array(img))
                    y.append(label)
                    paths.append(img_path)  # store the path
                except:
                    continue  # skip corrupted images

        data[s] = (np.array(X), np.array(y))
        paths_data[s] = paths

    train_x_orig, train_y_orig = data["train"]
    test_x_orig, test_y_orig = data["test"]

    train_paths = paths_data["train"]
    test_paths = paths_data["test"]

    # Normalize
    train_x = train_x_orig.astype(np.float32) / 255.0
    test_x  = test_x_orig.astype(np.float32) / 255.0

    train_y = train_y_orig.T
    test_y  = test_y_orig.T

    return train_x, train_y, train_paths, test_x, test_y, test_paths, np.array(classes)

# %%
train_x, train_y, train_paths, test_x, test_y, test_paths, classes = load_data_with_paths()
print(test_paths)
# Out:
# []

# %%
import os
import numpy as np
from PIL import Image

def load_data_with_paths(data_dir="dataset", img_size=(64, 64)):
    sets = ["train", "test"]
    classes = ["no_face", "face"]

    data = {}
    paths_data = {}

    for s in sets:
        X = []
        y = []
        paths = []

        for label, cls in enumerate(classes):
            class_dir = os.path.join(data_dir, s, cls)
            if not os.path.exists(class_dir):
                continue

            for file in os.listdir(class_dir):
                img_path = os.path.join(class_dir, file)
                try:
                    img = Image.open(img_path).convert("RGB")
                    img = img.resize(img_size)
                    X.append(np.array(img))
                    y.append(label)
                    paths.append(img_path)  # <-- keep the path
                except:
                    continue  # skip corrupted images

        data[s] = (np.array(X), np.array(y))
        paths_data[s] = np.array(paths)

    train_x_orig, train_y_orig = data["train"]
    test_x_orig, test_y_orig = data["test"]

    train_paths = paths_data["train"]
    test_paths = paths_data["test"]

    # Normalize
    train_x = train_x_orig.astype(np.float32) / 255.0
    test_x  = test_x_orig.astype(np.float32) / 255.0

    # Labels
    train_y = train_y_orig.T
    test_y  = test_y_orig.T

    return train_x, train_y, train_paths, test_x, test_y, test_paths, np.array(classes)

# %%
train_x, train_y, train_paths, test_x, test_y, test_paths, classes = load_data_with_paths()
print("Number of test paths:", len(test_paths))
print("First test path:", test_paths[0])
# Out:
# Number of test paths: 287
# First test path: dataset\test\no_face\010_0006.jpg

# %%
import face_recognition
import numpy as np
import matplotlib.pyplot as plt

# Example: store known faces in a dictionary
known_faces = {
    "Alice": face_recognition.face_encodings(face_recognition.load_image_file("alice.jpg"))[0],
    "Bob": face_recognition.face_encodings(face_recognition.load_image_file("bob.jpg"))[0],
}

# Function to test a new image
def test_face(img_path):
    img = face_recognition.load_image_file(img_path)
    encodings = face_recognition.face_encodings(img)
    
    if len(encodings) == 0:
        print("No face detected")
        return
    
    new_encoding = encodings[0]
    
    # Compare with known faces
    for name, known_encoding in known_faces.items():
        distance = np.linalg.norm(new_encoding - known_encoding)
        print(f"Distance to {name}: {distance:.3f}")
        if distance < 0.6:
            print(f"Match found: {name}")
            return
    
    print("No match found")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import face_recognition
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'face_recognition'

# %%
import random

idx = random.randint(0, len(test_paths)-1)
img_path = test_paths[idx]
test_face(img_path)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 3
#       1 import random
# ----> 3 idx = random.randint(0, len(test_paths)-1)
#       4 img_path = test_paths[idx]
#       5 test_face(img_path)
#
# File C:\Program Files\Python311\Lib\random.py:362, in Random.randint(self, a, b)
#     358 def randint(self, a, b):
#     359     """Return random integer in range [a, b], including both end points.
#     360     """
# --> 362     return self.randrange(a, b+1)
#
# File C:\Program Files\Python311\Lib\random.py:345, in Random.randrange(self, start, stop, step)
#     343     if width > 0:
#     344         return istart + self._randbelow(width)
# --> 345     raise ValueError("empty range for randrange() (%d, %d, %d)" % (istart, istop, width))
#     347 # Non-unit step argument supplied.
#     348 if istep > 0:
#
# ValueError: empty range for randrange() (0, 0, 0)
