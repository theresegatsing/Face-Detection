# %%
import time
import numpy as np
import h5py
#import matplotlib.pyplot as plt
import scipy
from PIL import Image
from scipy import ndimage
import os
from PIL import Image
import copy

# %%
def load_data(data_dir="dataset", img_size=(64, 64)):
    sets = ["train", "test"]
    classes = ["no_face", "face"]

    data = {}

    for s in sets:
        X = []
        y = []

        for label, cls in enumerate(classes):
            class_dir = os.path.join(data_dir, s, cls)

            for file in os.listdir(class_dir):
                img_path = os.path.join(class_dir, file)

                try:
                    img = Image.open(img_path).convert("RGB")
                    img = img.resize(img_size)
                    X.append(np.array(img))
                    y.append(label)
                except:
                    continue  # skip corrupted images

        data[s] = (np.array(X), np.array(y))

    train_x_orig, train_y_orig = data["train"]
    test_x_orig, test_y_orig = data["test"]
    
 
    # Normalize
    train_x = train_x_orig.astype(np.float32) / 255.0
    test_x  = test_x_orig.astype(np.float32) / 255.0
    
  
    train_y = train_y_orig
    test_y  = test_y_orig
    
    return train_x, train_y, test_x, test_y, np.array(classes)

# %%
train_x, train_y, test_x, test_y, classes = load_data()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense

model = Sequential()

# Input layer first
model.add(Input(shape=(64,64,3)))

# Convolution + ReLU + Pooling
model.add(Conv2D(32, (3,3), activation='relu'))
model.add(MaxPooling2D((2,2)))

# Another conv layer
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D((2,2)))

# Flatten for dense layer
model.add(Flatten())

# Fully connected layer
model.add(Dense(64, activation='relu'))

# Output layer
model.add(Dense(1, activation='sigmoid'))

# Compile model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(
    train_x, train_y,          # training data and labels
    epochs=10,                 # number of times to iterate over the dataset
    batch_size=32,             # number of examples per gradient update
    validation_data=(test_x, test_y)  # to track accuracy on test set
)
# Out:
# Epoch 1/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.5357 - loss: 0.8271 - val_accuracy: 0.3763 - val_loss: 0.6986
# Epoch 2/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.6205 - loss: 0.6698 - val_accuracy: 0.7596 - val_loss: 0.5766
# Epoch 3/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.6071 - loss: 0.6040 - val_accuracy: 0.8014 - val_loss: 0.5137
# Epoch 4/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.8393 - loss: 0.4843 - val_accuracy: 0.8571 - val_loss: 0.4186
# Epoch 5/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0.8661 - loss: 0.3579 - val_accuracy: 0.8850 - val_loss: 0.3284
# Epoch 6/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.9107 - loss: 0.2434 - val_accuracy: 0.9024 - val_loss: 0.2607
# Epoch 7/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.9464 - loss: 0.1681 - val_accuracy: 0.9164 - val_loss: 0.2474
# Epoch 8/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0.9554 - loss: 0.1236 - val_accuracy: 0.9129 - val_loss: 0.2153
# Epoch 9/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.9598 - loss: 0.1026 - val_accuracy: 0.9129 - val_loss: 0.2303
# Epoch 10/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.9688 - loss: 0.0999 - val_accuracy: 0.9233 - val_loss: 0.1735

# %%
loss, accuracy = model.evaluate(test_x, test_y)
print(f"Test Accuracy: {accuracy*100:.2f}%")
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9233 - loss: 0.1735
# Test Accuracy: 92.33%

# %%
predictions = model.predict(test_x)
predicted_labels = (predictions > 0.5).astype(int)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'], label='train acc')
plt.plot(history.history['val_accuracy'], label='val acc')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import time
import random
import numpy as np

def live_test_random_images_cnn(test_x, test_y, classes, model, delay=2):
    """
    Randomly shows test images every `delay` seconds and predicts using a trained CNN.
    
    Arguments:
    test_x -- test images, shape (m, 64, 64, 3)
    test_y -- true labels, shape (m, 1)
    classes -- array like ['no_face', 'face']
    model -- trained Keras CNN model
    delay -- seconds between predictions
    """
    
    num_examples = test_x.shape[0]
    
    while True:
        idx = random.randint(0, num_examples - 1)
        
        img = test_x[idx]              # shape (64, 64, 3)
        true_label = test_y[idx][0]
        
        # Show image
        plt.imshow(img)
        plt.axis('off')
        plt.show(block=False)
        plt.pause(0.001)
        
        # Predict (model expects batch dimension)
        img_input = np.expand_dims(img, axis=0)  # (1, 64, 64, 3)
        prob = model.predict(img_input, verbose=0)[0][0]
        pred = int(prob > 0.5)
        
        print(
            f"Prediction: {classes[pred]} "
            f"(prob={prob:.2f}) | True label: {classes[true_label]}"
        )
        
        plt.close()
        time.sleep(delay)

# %%
classes = ['no_face', 'face']

live_test_random_images_cnn(
    test_x,
    test_y,
    classes,
    model,
    delay=2
)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[28], line 3
#       1 classes = ['no_face', 'face']
# ----> 3 live_test_random_images_cnn(
#       4     test_x,
#       5     test_y,
#       6     classes,
#       7     model,
#       8     delay=2
#       9 )
#
# Cell In[27], line 24, in live_test_random_images_cnn(test_x, test_y, classes, model, delay)
#      21 idx = random.randint(0, num_examples - 1)
#      23 img = test_x[idx]              # shape (64, 64, 3)
# ---> 24 true_label = test_y[idx][0]
#      26 # Show image
#      27 plt.imshow(img)
#
# IndexError: invalid index to scalar variable.
